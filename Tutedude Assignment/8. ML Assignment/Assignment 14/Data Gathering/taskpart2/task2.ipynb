# %%
import pandas as pd
import json

# %%
with open("products.json", "r") as file:
    data = json.load(file)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       is_member_price member_show_price member_price is_parent_product  \
# 0                                 FALSE            0
# 1                                 FALSE            0
# 2                                 FALSE            0
# 3                                 FALSE            0
# 4                                 FALSE            0
# ...               ...               ...          ...               ...
# 12727                             FALSE            0
# 12728                             FALSE            0
# 12729                             FALSE            0
# 12730                             FALSE            0
# 12731                             FALSE            0
#
#       profit_percentage message_main_attachment_id company_id  \
# 0                     0                                     2
# 1                     0                                     2
# 2                     0                                     2
# ...

# %%
df.columns
# Out:
# Index(['is_member_price', 'member_show_price', 'member_price',
#        'is_parent_product', 'profit_percentage', 'message_main_attachment_id',
#        'company_id', 'name', 'description', 'detailed_type', 'types', 'weight',
#        'to_weight', 'volume', 'product_sequence', 'sequence', 'previous_price',
#        'previous_price_date', 'uom_id', 'can_image_varient_1024_be_zoomed',
#        'active', 'list_price', 'barcode', 'available_in_pos',
#        'pos_category_id', 'categ_id', 'case_cost', 'unit_in_case',
#        'unit_of_measure', 'ebt_product', 'otc_product', 'margin', 'markup',
#        'cp_margin', 'product_tmpl_id', 'create_uid', 'band', 'published',
#        'size', 'visibility', 'is_custom_product', 'is_no_discountable_product',
#        'sku', 'is_valid_quantity_discount', 'quantity_update_using_barcode',
#        'is_variant', 'combination_indices', 'create_date',
#        'x_times_loyalty_point', 'is_no_loyalty', 'is_increase_loyalty_point',
# ...

# %%
df.dtypes
# Out:
# is_member_price       str
# member_show_price     str
# member_price          str
# is_parent_product     str
# profit_percentage     str
#                      ...
# write_date            str
# ewic                  str
# date_exprire_moved    str
# write_uid             str
# default_code          str
# Length: 66, dtype: object
