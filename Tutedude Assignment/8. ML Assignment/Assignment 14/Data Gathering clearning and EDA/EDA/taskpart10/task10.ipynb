# %% [markdown]
# # Insights & Observations
#
# 1. G1 and G2 have a strong positive correlation with G3.
# 2. Male and female students have similar average final grades.
# 3. Most students score between 8 and 15 in the final exam.
# 4. The absences column contains a few outliers.
# 5. The dataset has no significant missing values or duplicate records.
# 6. Categorical columns were successfully encoded for analysis.
# 7. Numerical features show different distributions and ranges.
# 8. Correlation analysis shows G2 is the strongest predictor of G3.
# 9. Students with higher G1 and G2 scores generally achieve higher G3 scores.
# 10. The dataset is clean and suitable for machine learning and statistical analysis.
