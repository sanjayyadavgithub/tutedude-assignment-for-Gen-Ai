# %% [markdown]
# ## Assignment 5:

# %% [markdown]
# #### Task 1: Create A Module (math_utils)

# %%
print("Math Utilities Program without methods for addition, subtraction, multiplication, division, and squaring.")
import math_utils as mu
print("Sum of 5 and 10 is: ", mu.add(5, 10))
print("Difference of 10 and 5 is: ", mu.subtract(10, 5))
print("Product of 5 and 10 is: ", mu.multiply(5, 10))
print("Quotient of 10 and 5 is: ", mu.divide(10, 5))
print("Square of 5 is: ", mu.squareOfNumber(5))
# Out:
# Math Utilities Program without methods for addition, subtraction, multiplication, division, and squaring.
# Sum of 5 and 10 is:  15
# Difference of 10 and 5 is:  5
# Product of 5 and 10 is:  50
# Quotient of 10 and 5 is:  2.0
# Square of 5 is:  25

# %%
print("Math Utilities Program with as methods for addition, subtraction, multiplication, division, and squaring.")
from math_utils import add, subtract, multiply, divide, squareOfNumber
print("Sum of 5 and 10 is: ", add(5, 10))
print("Difference of 10 and 5 is: ", subtract(10, 5))
print("Product of 5 and 10 is: ", multiply(5, 10))
print("Quotient of 10 and 5 is: ", divide(10, 5))
print("Square of 5 is: ", squareOfNumber(5))
# Out:
# Math Utilities Program with as methods for addition, subtraction, multiplication, division, and squaring.
# Sum of 5 and 10 is:  15
# Difference of 10 and 5 is:  5
# Product of 5 and 10 is:  50
# Quotient of 10 and 5 is:  2.0
# Square of 5 is:  25

# %% [markdown]
# ### Task 2: Create A Module (string_utils.py)

# %%
import string_utils as su
input_string = "hello world from python"
capitalized_string = su.capitalize_words(input_string)
reversed_string = su.reverse_string(input_string)
word_count = su.count_words(input_string)
print("Original String: ", input_string)
print("Capitalized String: ", capitalized_string)
print("Reversed String: ", reversed_string)
print("Word Count: ", word_count)
# Out:
# Original String:  hello world from python
# Capitalized String:  Hello World From Python
# Reversed String:  nohtyp morf dlrow olleh
# Word Count:  4

# %% [markdown]
# ### Task 3: Create A Simple Package(shop_package)

# %%
# create a dictionary / Package of shop_package
# in shop_package create two files discount.py and billing.py
# in discount.py create two functions apply_discount and flat_discount
# in billing.py create two functions calculate_total and apply_tax

# %% [markdown]
# ### Task 4: Importing All Package in Main File

# %%
import shop_package.discount as disc
import shop_package.billing as bill

print("Applying percentage discount of 10% on price 100: ", disc.apply_discount(100, 10))
print("Applying flat discount of 50 on price 200: ", disc.flat_discount(200))
print("Calculating total of prices [100, 200, 300]: ", bill.calculate_total([100, 200, 300]))
print("Applying tax on amount 500: ", bill.apply_tax(500))
# Out:
# Applying percentage discount of 10% on price 100:  90.0
# Applying flat discount of 50 on price 200:  150
# Calculating total of prices [100, 200, 300]:  600
# Applying tax on amount 500:  525.0
