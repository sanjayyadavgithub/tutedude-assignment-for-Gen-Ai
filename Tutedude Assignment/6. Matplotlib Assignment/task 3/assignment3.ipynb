# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Walmart_Sales.csv")
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='str')

# %%
temp_by_store = df.groupby('Store')['Temperature'].mean()
temp_by_store
# Out:
# Store
# 1     68.306783
# 2     68.216364
# 3     71.434196
# 4     62.253357
# 5     69.410140
# 6     69.700000
# 7     39.720280
# 8     62.513986
# 9     67.775175
# 10    72.241189
# 11    72.480769
# 12    70.262797
# 13    53.697133
# 14    57.790979
# 15    51.833846
# 16    45.030070
# 17    46.387203
# 18    53.371259
# 19    52.295035
# 20    55.451399
# 21    68.847622
# 22    54.897133
# 23    48.805105
# 24    54.030000
# 25    52.138392
# 26    43.658252
# 27    57.311119
# 28    70.262797
# 29    54.897133
# 30    68.847622
# 31    68.847622
# 32    52.747552
# 33    76.728182
# 34    58.495874
# 35    57.311119
# 36    71.160350
# 37    71.160350
# 38    70.262797
# 39    70.597343
# 40    47.674545
# 41    48.410350
# 42    72.241189
# 43    68.877692
# 44    53.697133
# 45    57.790979
# Name: Temperature, dtype: float64

# %% [markdown]
# ### vertical bar chart

# %%
plt.figure(figsize=(14, 6))
temp_by_store.plot(kind='bar')
plt.title('Average Temperature by Store')
plt.xlabel('Store')
plt.ylabel('Temperature')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### horizontal bar chart

# %%
plt.figure(figsize=(6, 12))
temp_by_store.plot(kind='barh')
plt.title('Average Temperature by Store')
plt.xlabel('Temperature')
plt.ylabel('Store')
plt.yticks(rotation=45, ha='right')
plt.show()
